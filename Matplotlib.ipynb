# %%
import pandas as pd
import matplotlib.pyplot as plt
world = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/2018-2019 Happiness.csv')
airbnb = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/airbnb.csv')
salaries = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/salaries.csv')
sales = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/web_sales.csv')
eth = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/All+course+files/All course files/Python Section/Ethereum Historical Data.csv', index_col = 0)

# %%
average_sales = [20000, 25000,32000,35000,40000]
years = [2015,2016,2017,2018,2019]

# %%
plt.plot(years, average_sales)
# (x,y)
#if you want a bar add plt.bar and it would show bar graph

# %%
plt.plot(years, average_sales)
plt.show() #when you add show it removes thr wording "<matplotlib.lines.Line2D at 0x13307b5c0>" at the top

# %%
plt.bar(years, average_sales)
plt.show()

# %%
#adding labels and titles

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries.groupby('experience_level')['salary_in_usd'].mean()
# Out:
# experience_level
# EN     87676.762821
# EX    189052.617100
# MI    114681.021363
# SE    161889.010574
# Name: salary_in_usd, dtype: float64

# %%
avg_salary_exp = salaries.groupby('experience_level')['salary_in_usd'].mean().reset_index()
#covert to a datafram add reset index

# %%
avg_salary_exp
# Out:
#   experience_level  salary_in_usd
# 0               EN   87676.762821
# 1               EX  189052.617100
# 2               MI  114681.021363
# 3               SE  161889.010574

# %%
plt.bar(avg_salary_exp['experience_level'], avg_salary_exp['salary_in_usd'])
# Out:
# <BarContainer object of 4 artists>

# %%
#we can rearrange and have the highest bar on the left
avg_salary_exp = salaries.groupby('experience_level')\
                ['salary_in_usd'].mean().reset_index()\
                .sort_values(by= 'salary_in_usd', ascending = False)

# %%
plt.bar(avg_salary_exp['experience_level'], avg_salary_exp['salary_in_usd'])
# Out:
# <BarContainer object of 4 artists>

# %%
#adding x and y label and title 
plt.bar(avg_salary_exp['experience_level'], avg_salary_exp['salary_in_usd'])
plt.xlabel('Experience_level')
plt.ylabel('Average Salary')
plt.title('Average Salary Against Experience')
# Out:
# Text(0.5, 1.0, 'Average Salary Against Experience')

# %%
#Histogram
airbnb
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4          500  26/06/2008             Trendy Times Square Loft     Manhattan
# ...        ...         ...                                  ...           ...
# 9769   3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
# 9770   3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771   3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772   3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
plt.hist(airbnb['Beds'], bins = 5)
# Out:
# (array([9.314e+03, 4.000e+02, 1.600e+01, 9.000e+00, 6.000e+00]),
#  array([ 0. ,  3.2,  6.4,  9.6, 12.8, 16. ]),
#  <BarContainer object of 5 artists>)

# %%
reviewed_records = airbnb[airbnb['Review Scores Rating'].notna()] 
#making a histogram but we excluded the nulls in the review scores rating

# %%
plt.hist(reviewed_records['Review Scores Rating'])
# Out:
# (array([6.000e+00, 0.000e+00, 9.000e+00, 2.000e+00, 2.000e+00, 5.900e+01,
#         1.060e+02, 6.120e+02, 2.045e+03, 5.185e+03]),
#  array([ 20.,  28.,  36.,  44.,  52.,  60.,  68.,  76.,  84.,  92., 100.]),
#  <BarContainer object of 10 artists>)

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
plt.hist (salaries ['salary_in_usd'], bins = 20)
# Out:
# (array([2.590e+02, 8.150e+02, 1.149e+03, 1.675e+03, 1.730e+03, 1.256e+03,
#         8.890e+02, 5.170e+02, 2.380e+02, 1.520e+02, 6.500e+01, 3.800e+01,
#         1.400e+01, 6.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([ 15000.  ,  45010.05,  75020.1 , 105030.15, 135040.2 , 165050.25,
#         195060.3 , 225070.35, 255080.4 , 285090.45, 315100.5 , 345110.55,
#         375120.6 , 405130.65, 435140.7 , 465150.75, 495160.8 , 525170.85,
#         555180.9 , 585190.95, 615201.  ]),
#  <BarContainer object of 20 artists>)

# %%
#adding edge colour - adding a border around your bars
plt.hist (salaries ['salary_in_usd'], bins = 20, edgecolor= 'black', color = 'teal')
plt.xlabel('Salary in USD')
plt.ylabel('Frequency')
plt.title('Histogram of Salaries')
plt.show()

# %%
#PIECHARTS

# %%
countries = ['USA', 'Japan', 'UK', 'Germany']
profits = [50000, 600000, 300000,400000]

plt.pie(profits, labels = countries)
plt.show ()

# %%
#adding labels and percentage

# %%
countries = ['USA', 'Japan', 'UK', 'Germany']
profits = [50000, 600000, 300000,400000]

plt.pie(profits, labels = countries, autopct = '%1.1f%%', explode = [0.3, 0, 0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x138320470>,
# ...
#  [Text(1.3905337006978207, 0.16253008098079605, 'USA'),
#   Text(-0.06395932512941842, 1.0981389733221336, 'Japan'),
#   Text(-0.9190365757857505, -0.6044599013731207, 'UK'),
#   Text(0.6568744860588955, -0.8823354858356667, 'Germany')],
#  [Text(0.8939145218771705, 0.10448362348765458, '3.7%'),
#   Text(-0.034886904616046405, 0.5989848945393456, '44.4%'),
#   Text(-0.5012926777013184, -0.32970540074897486, '22.2%'),
#   Text(0.358295174213943, -0.48127390136490905, '29.6%')])

# %%
#scatter plots
#postive corealtion
ages = [20,25,30,35,40]
salaries = [25000,30000,35000,40000,45000] 
plt.scatter(ages,salaries, color = "y")

# %%
#Negative corealtion
ages_n = [40,35,30,25,20]
salaries =[25000,30000,35000,40000,45000]
plt.scatter(ages_n,salaries, color = "b")

# %%
#no correlaton
ages_no = [40,35,30,25,20]
salaries_no =[27000,52000,60000,49000,57000] 
plt.scatter(ages_no,salaries_no, color = "b")

# %%
plt.scatter(sales['SalesAmount'], sales ['Freight'], color = 'red', marker = '*')

# %%
plt.scatter(world['Healthy life expectancy'], world ['Score'], alpha = 0.5)
plt.grid(True)
plt.xlabel('Healthy life expectancy')
plt.ylabel('Score')
#alpha to show the overlaps
# Out:
# Text(0, 0.5, 'Score')

# %%
#line chart
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
plt.plot(eth.index, eth['Price'])

# %%
eth.index = pd.to_datetime(eth.index, format = "%d/%m/%Y")
#change the index into date

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 2024-02-10  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 2024-02-09  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2024-02-08  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 2024-02-07  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 2024-02-06  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 2020-01-05  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 2020-01-04  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 2020-01-03  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2020-01-02  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 2020-01-01  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
plt.plot(eth.index, eth['Price'])

# %%
#cleaning it up and add labeles
plt.plot(eth.index, eth['Price'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Ethereum Price')
plt.xticks(rotation =45)
plt.show()

# %%
#setting the size 
plt.figure(figsize = (6,4), dpi = 120)
plt.plot(eth.index, eth['Price'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Ethereum Price')
plt.xticks(rotation =45)
plt.show()
 #showing two charts in one frame

plt.figure(figsize = (6,4), dpi = 120)
plt.plot(eth.index, eth['High'], color = 'orange')
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Ethereum Price Chart')
plt.xticks(rotation =45)
plt.show()

# %%
#SHOWING FRAME SIDE BY SIDE (3 OR MORE)
plt.figure(figsize = (11,4), dpi = 120) #<---- Keep this for the first one
plt.subplot (1,3,1) #1 row with 3 columns
plt.plot(eth.index, eth['Price'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Ethereum Closing Price')
plt.xticks(rotation =45)

 
#CHART 2

plt.subplot (1,3,2)
plt.plot(eth.index, eth['High'], color = 'orange')
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Ethereum High Price Chart')
plt.xticks(rotation =45)


#
#CHART 3 
plt.subplot (1,3,3)
plt.plot(eth.index, eth['Low'], color = 'red')
plt.xlabel('Date')
plt.ylabel('Low')
plt.title('Ethereum Low Price Chart')
plt.xticks(rotation =45)
plt.tight_layout()
plt.show()

# %%
sales.head(5)
# Out:
#    ProductKey                  product product_subcategory  OrderDateKey  \
# 0         310         Road-150 Red, 62          Road Bikes      20101229
# 1         346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2         346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3         336       Road-650 Black, 62          Road Bikes      20101229
# 4         346  Mountain-100 Silver, 44      Mountain Bikes      20101229
#
#    CalendarYear SalesTerritoryRegion SalesTerritoryCountry SalesOrderNumber  \
# 0          2010               Canada                Canada          SO43697
# 1          2010               France                France          SO43698
# 2          2010            Northwest         United States          SO43699
# 3          2010            Southwest         United States          SO43700
# 4          2010            Australia             Australia          SO43701
#
#    SalesAmount    TaxAmt  Freight
# 0    3578.2700  286.2616  89.4568
# ...

# %%
bike_sales = sales[sales['product_subcategory'].isin(['Road Bikes', 'Mountain Bikes', 'Touring Bikes' ])]

# %%
bike_sales_grp = bike_sales.groupby('product_subcategory')['SalesAmount'].sum().reset_index()

# %%
accessory_sales = sales[~sales['product_subcategory'].isin(['Road Bikes', 'Mountain Bikes', 'Touring Bikes' ])]

# %%
accessory_sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 5429          479         Road Bottle Cage   Bottles and Cages      20121228
# 5431          217  Sport-100 Helmet, Black             Helmets      20121228
# 5433          478     Mountain Bottle Cage   Bottles and Cages      20121228
# 5434          477    Water Bottle - 30 oz.   Bottles and Cages      20121228
# 5436          540             HL Road Tire     Tires and Tubes      20121228
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
accessory_sales_grp = accessory_sales.groupby('product_subcategory')\
                    ['SalesAmount'].sum().reset_index().sort_values(by = 'SalesAmount', ascending = False)

# %%
accessory_sales_grp
# Out:
#    product_subcategory  SalesAmount
# 12     Tires and Tubes    245529.32
# 7              Helmets    225335.60
# 9              Jerseys    172950.68
# 10              Shorts     71319.81
# 2    Bottles and Cages     56798.19
# 5              Fenders     46619.58
# 8      Hydration Packs     40307.67
# 1          Bike Stands     39591.00
# 0           Bike Racks     39360.00
# 13               Vests     35687.00
# 6               Gloves     35020.70
# 3                 Caps     19688.10
# 4             Cleaners      7218.60
# 11               Socks      5106.32

# %%
plt.pie(bike_sales_grp['SalesAmount'], labels = bike_sales_grp ['product_subcategory'])
# Out:
# ([<matplotlib.patches.Wedge at 0x139960470>,
# ...
#  [Text(0.4948817174501019, 0.982391004505659, 'Mountain Bikes'),
#   Text(-0.8569791039026488, -0.6896280268914636, 'Road Bikes'),
#   Text(1.0014433493330255, -0.45509473527679034, 'Touring Bikes')])

# %%
plt.barh (accessory_sales_grp['product_subcategory'], accessory_sales_grp['SalesAmount'])
# Out:
# <BarContainer object of 14 artists>

# %%
#total sales a month
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
#total sales a month
sales['OrderDate'] = pd.to_datetime(sales['OrderDateKey'], format = '%Y%m%d')
sales ['MonthYear'] = pd.to_datetime (sales['OrderDate'].dt.strftime ('%Y -%m'))
sales
# Out:
# /var/folders/st/h_t90lqj4xg_xvzb072ycctr0000gn/T/ipykernel_3036/268863100.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales ['MonthYear'] = pd.to_datetime (sales['OrderDate'].dt.strftime ('%Y -%m'))
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# ...

# %%
monthly_sales = sales.groupby('MonthYear')['SalesAmount'].sum().reset_index()

# %%
plt.plot(monthly_sales['MonthYear'], monthly_sales['SalesAmount'])
plt.show()

# %%
monthly_sales = sales.groupby('MonthYear')['SalesAmount'].sum().reset_index()
daily_sales = sales.groupby('OrderDate')['SalesAmount'].sum().reset_index()

# %%
plt.plot(daily_sales['OrderDate'], daily_sales['SalesAmount'])
plt.show()

# %%
country_sales = sales.groupby('SalesTerritoryCountry')['SalesAmount']\
                .sum().reset_index().sort_values(by = "SalesAmount", ascending = False)

# %%
plt.barh(country_sales['SalesTerritoryCountry'], country_sales['SalesAmount'])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.style.use('fivethirtyeight')
plt.rcdefaults()

# %%
plt.figure(figsize =(12,8))

plt.subplot (2,2,1)
#Line Chart
plt.plot(monthly_sales['MonthYear'], monthly_sales['SalesAmount'], marker = '.', linestyle = '--', linewidth = 3, color = 'yellow' )
plt.xticks(rotation = 45, fontsize = 10, color = 'blue')
plt.title ('Sales by month', fontweight = 'bold')
plt.xlabel('Month-Year', fontsize = 10)
plt.ylabel('Sales', fontsize = 10)


plt.subplot (2,2,2)
#Horizontal Bar chart
plt.barh (accessory_sales_grp['product_subcategory'], accessory_sales_grp['SalesAmount'], color = 'green')

plt.title ('Accessory Sale', fontweight = 'bold')




plt.subplot (2,2,3)
#pie Chart
plt.pie(bike_sales_grp['SalesAmount'], labels = bike_sales_grp ['product_subcategory'], autopct = '%1.1ff%%', colors = ['blue', 'red','orange'])
plt.title ('Bike Sale', fontweight = 'bold')



plt.subplot (2,2,4)
#Bar Chart
plt.bar(country_sales['SalesTerritoryCountry'], country_sales['SalesAmount'], color = 'violet')
plt.xticks (rotation = 45)
plt.title ('Country Sales', fontweight = 'bold')
plt.xlabel('Country', fontsize = 10)
plt.ylabel('Sales', fontsize = 10)

plt.tight_layout()
